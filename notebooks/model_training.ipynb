# %% [markdown]
# # Model training (placeholder)
#
# Planned sections:
# - Train/val/test split (prefer patient-level split)
# - Transfer learning with ResNet50 / EfficientNet
# - Handle class imbalance (weighted loss, sampling)
# - Save checkpoints for backend integration
