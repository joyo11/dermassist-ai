# %% [markdown]
# # Dataset exploration (placeholder)
#
# Planned sections:
# - Load metadata CSV(s) (HAM10000 / ISIC)
# - Inspect label distribution, missing values
# - Decide label mapping for binary/multiclass experiments
# - Visualize samples and augmentations
